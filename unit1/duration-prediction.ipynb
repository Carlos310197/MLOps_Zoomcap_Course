# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_parquet('./data/green_tripdata_2021-01.parquet')
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag
# 0             2  2021-01-01 00:15:56   2021-01-01 00:19:52                  N  \
# 1             2  2021-01-01 00:25:59   2021-01-01 00:34:44                  N
# 2             2  2021-01-01 00:45:57   2021-01-01 00:51:55                  N
# 3             2  2020-12-31 23:57:51   2021-01-01 00:04:56                  N
# 4             2  2021-01-01 00:16:36   2021-01-01 00:16:40                  N
# ...         ...                  ...                   ...                ...
# 76513         2  2021-01-31 21:38:00   2021-01-31 22:16:00               None
# 76514         2  2021-01-31 22:43:00   2021-01-31 23:21:00               None
# 76515         2  2021-01-31 22:16:00   2021-01-31 22:27:00               None
# 76516         2  2021-01-31 23:10:00   2021-01-31 23:37:00               None
# 76517         2  2021-01-31 23:25:00   2021-01-31 23:35:00               None
#
# ...

# %% [markdown]
# All datatypes are correct

# %%
df.dtypes
# Out:
# VendorID                          int64
# lpep_pickup_datetime     datetime64[ns]
# lpep_dropoff_datetime    datetime64[ns]
# store_and_fwd_flag               object
# RatecodeID                      float64
# PULocationID                      int64
# DOLocationID                      int64
# passenger_count                 float64
# trip_distance                   float64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# ehail_fee                        object
# improvement_surcharge           float64
# total_amount                    float64
# payment_type                    float64
# trip_type                       float64
# congestion_surcharge            float64
# dtype: object

# %% [markdown]
# Find duration of the rides (in minutes)

# %%
df['duration'] = df['lpep_dropoff_datetime'] - df['lpep_pickup_datetime']
df['duration'] = df['duration'].apply(lambda td: td.total_seconds() / 60) # duration in minutes

# %%
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag
# 0             2  2021-01-01 00:15:56   2021-01-01 00:19:52                  N  \
# 1             2  2021-01-01 00:25:59   2021-01-01 00:34:44                  N
# 2             2  2021-01-01 00:45:57   2021-01-01 00:51:55                  N
# 3             2  2020-12-31 23:57:51   2021-01-01 00:04:56                  N
# 4             2  2021-01-01 00:16:36   2021-01-01 00:16:40                  N
# ...         ...                  ...                   ...                ...
# 76513         2  2021-01-31 21:38:00   2021-01-31 22:16:00               None
# 76514         2  2021-01-31 22:43:00   2021-01-31 23:21:00               None
# 76515         2  2021-01-31 22:16:00   2021-01-31 22:27:00               None
# 76516         2  2021-01-31 23:10:00   2021-01-31 23:37:00               None
# 76517         2  2021-01-31 23:25:00   2021-01-31 23:35:00               None
#
# ...

# %% [markdown]
# ### Let's look at the distribution of the duration

# %%
sns.displot(df['duration'], kde=True, bins=50)

# %% [markdown]
# Heavily tailed distribution

# %%
df.duration.describe()
# Out:
# count    76518.000000
# mean        19.927896
# std         59.338594
# min          0.000000
# 25%          8.000000
# 50%         13.883333
# 75%         23.000000
# max       1439.600000
# Name: duration, dtype: float64

# %% [markdown]
# As we can see in the percentiles and in the histogram, the duration it's really variable

# %%
df.duration.describe(percentiles=[0.95, 0.98, 0.99])
# Out:
# count    76518.000000
# mean        19.927896
# std         59.338594
# min          0.000000
# 50%         13.883333
# 95%         44.000000
# 98%         56.000000
# 99%         67.158167
# max       1439.600000
# Name: duration, dtype: float64

# %% [markdown]
# So, most of the trips (98-percentile) have a duration of around 60 minutes or 1 hour

# %% [markdown]
# Let's compute the percentage of total rides that have a duration of more than 1 minute and less than 60 minutes

# %%
((df.duration >= 1) & (df.duration <= 60)).mean()
# Out:
# 0.9658903787344154

# %%
df = df[(df.duration >= 1) & (df.duration <= 60)]
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag
# 0             2  2021-01-01 00:15:56   2021-01-01 00:19:52                  N  \
# 1             2  2021-01-01 00:25:59   2021-01-01 00:34:44                  N
# 2             2  2021-01-01 00:45:57   2021-01-01 00:51:55                  N
# 3             2  2020-12-31 23:57:51   2021-01-01 00:04:56                  N
# 7             2  2021-01-01 00:26:31   2021-01-01 00:28:50                  N
# ...         ...                  ...                   ...                ...
# 76513         2  2021-01-31 21:38:00   2021-01-31 22:16:00               None
# 76514         2  2021-01-31 22:43:00   2021-01-31 23:21:00               None
# 76515         2  2021-01-31 22:16:00   2021-01-31 22:27:00               None
# 76516         2  2021-01-31 23:10:00   2021-01-31 23:37:00               None
# 76517         2  2021-01-31 23:25:00   2021-01-31 23:35:00               None
#
# ...

# %% [markdown]
# ### Filter the columns we need for predicting

# %%
categorical = ['PULocationID', 'DOLocationID']
numerical = ['trip_distance']

# %% [markdown]
# ### Categorical variables

# %%
df[categorical].dtypes
# Out:
# PULocationID    int64
# DOLocationID    int64
# dtype: object

# %% [markdown]
# We need to do one-hot encoding to these categorical values. For this, we could use `dictionary-vectorizer` that needs that data in string format to perform one-hot encoding to the non-numerical variables

# %%
df[categorical] = df[categorical].astype(str)
# Out:
# /var/folders/_v/zn_c830s4vs0m1_wl8r0w3gw0000gn/T/ipykernel_41622/1767203464.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[categorical] = df[categorical].astype(str)

# %%
df[categorical].dtypes
# Out:
# PULocationID    object
# DOLocationID    object
# dtype: object

# %%
train_dicts = df[categorical + numerical].to_dict(orient='records')
train_dicts[:10] # only to see how the dictionary loooks like
# Out:
# [{'PULocationID': '43', 'DOLocationID': '151', 'trip_distance': 1.01},
#  {'PULocationID': '166', 'DOLocationID': '239', 'trip_distance': 2.53},
#  {'PULocationID': '41', 'DOLocationID': '42', 'trip_distance': 1.12},
#  {'PULocationID': '168', 'DOLocationID': '75', 'trip_distance': 1.99},
#  {'PULocationID': '75', 'DOLocationID': '75', 'trip_distance': 0.45},
#  {'PULocationID': '225', 'DOLocationID': '265', 'trip_distance': 12.19},
#  {'PULocationID': '244', 'DOLocationID': '244', 'trip_distance': 3.39},
#  {'PULocationID': '75', 'DOLocationID': '213', 'trip_distance': 6.69},
#  {'PULocationID': '74', 'DOLocationID': '238', 'trip_distance': 2.34},
#  {'PULocationID': '74', 'DOLocationID': '60', 'trip_distance': 5.48}]

# %%
dv = DictVectorizer()
X_train = dv.fit_transform(train_dicts)

# %% [markdown]
# #### Feature matrix

# %%
X_train
# Out:
# <73908x507 sparse matrix of type '<class 'numpy.float64'>'
# 	with 221724 stored elements in Compressed Sparse Row format>

# %% [markdown]
# Here, we can see the one-hot encoding stored in the `dv` object

# %%
dv.feature_names_
# Out:
# ['DOLocationID=1',
#  'DOLocationID=10',
#  'DOLocationID=100',
#  'DOLocationID=101',
#  'DOLocationID=102',
#  'DOLocationID=106',
#  'DOLocationID=107',
#  'DOLocationID=108',
#  'DOLocationID=109',
#  'DOLocationID=11',
#  'DOLocationID=111',
#  'DOLocationID=112',
#  'DOLocationID=113',
#  'DOLocationID=114',
#  'DOLocationID=115',
#  'DOLocationID=116',
#  'DOLocationID=117',
#  'DOLocationID=118',
#  'DOLocationID=119',
#  'DOLocationID=12',
#  'DOLocationID=120',
#  'DOLocationID=121',
#  'DOLocationID=122',
#  'DOLocationID=123',
#  'DOLocationID=124',
#  'DOLocationID=125',
#  'DOLocationID=126',
#  'DOLocationID=127',
#  'DOLocationID=128',
#  'DOLocationID=129',
#  'DOLocationID=13',
#  'DOLocationID=130',
#  'DOLocationID=131',
#  'DOLocationID=132',
#  'DOLocationID=133',
#  'DOLocationID=134',
#  'DOLocationID=135',
#  'DOLocationID=136',
#  'DOLocationID=137',
#  'DOLocationID=138',
#  'DOLocationID=139',
#  'DOLocationID=14',
#  'DOLocationID=140',
# ...

# %%
target = 'duration'
y_train = df[target].values

# %% [markdown]
# #### Target vector

# %%
y_train
# Out:
# array([ 3.93333333,  8.75      ,  5.96666667, ..., 11.        ,
#        27.        , 10.        ])

# %% [markdown]
# ## Create and Train our Linear Regression Model

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_train)

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.histplot(y_pred, bins=50, kde=True, stat="density", element="step", label='prediction', ax=ax)
sns.histplot(y_train, bins=50, kde=True, stat="density", element="step", label='groundtruth', ax=ax)
plt.legend()

# %% [markdown]
# Not really good performace, as we can see. And this is only with the training data.

# %%
mean_squared_error(y_train, y_pred, squared=False)
# Out:
# 9.838799799829626

# %% [markdown]
# # Let's order the code a little bit...

# %%
def read_dataframe(filename):
    """Function to read the dataframe and perform preprocessing"""
    
    df = pd.read_parquet(filename)
    df['duration'] = df['lpep_dropoff_datetime'] - df['lpep_pickup_datetime']
    df['duration'] = df['duration'].apply(lambda td: td.total_seconds() / 60) # duration in minutes
    df = df[(df.duration >= 1) & (df.duration <= 60)]
    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = read_dataframe('./data/green_tripdata_2021-01.parquet')
df_val = read_dataframe('./data/green_tripdata_2021-02.parquet')

# %%
len(df_train), len(df_val)
# Out:
# (73908, 61921)

# %% [markdown]
# First, find the feature matrix

# %%
categorical = ['PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %% [markdown]
# Now, train the Linear Regression model

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred, squared=False)
# Out:
# 10.499110710362512

# %% [markdown]
# And the Lasso model (L1 norm regularization)

# %%
lr = Lasso(alpha=0.1)
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred, squared=False)
# Out:
# 11.674811916671658
